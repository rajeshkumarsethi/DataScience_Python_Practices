# %%
import pandas as pd
import numpy as np

# %%
stores = pd.read_excel("C:/Users/DELL/Desktop/DS_Vikas_Class/Python_Class1/Retail_data.xlsx" , sheet_name = 'storesdata')

# %%
stores.columns.to_list()
# Out:
# ['Code',
#  'StoreType',
#  'OperatingCost',
#  'Total_Sales',
#  'Total_Customers',
#  'Segment',
#  'Total number of estb',
#  'Product line sales as % of total sales']

# %%
stores.head()
# Out:
#    Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0     1  Electronincs           21.0   2179474632              110        4
# 1     2       Apparel           21.0      5037027              110        4
# 2     3  Super Market           22.8   1437362017               93        1
# 3     4  Super Market           21.4   1495953548              110        1
# 4     5  Super Market           18.7   1883321582              175        2
#
#    Total number of estb  Product line sales as % of total sales
# 0                361300                                    29.6
# 1                  2515                                     5.7
# 2                200112                                     5.9
# 3                229623                                     4.6
# 4                270472                                    24.7

# %%
stores.tail()
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 29    30       Apparel           19.7    393363810              175        4
# 30    31       Apparel           15.0   1115016252              335        4
# 31    32  Electronincs           21.4   1237304404              109        2
# 32    31       Apparel           15.0   1115016252              335        4
# 33    32  Electronincs           21.4   1237304404              109        2
#
#     Total number of estb  Product line sales as % of total sales
# 29                 17840                                     4.2
# 30                125658                                     7.5
# 31                123206                                     6.4
# 32                125658                                     7.5
# 33                123206                                     6.4

# %%
stores.shape
# Out:
# (34, 8)

# %%
stores.shape[0]
# Out:
# 34

# %%
stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Code                                    34 non-null     int64
#  1   StoreType                               34 non-null     object
#  2   OperatingCost                           34 non-null     float64
#  3   Total_Sales                             34 non-null     int64
#  4   Total_Customers                         34 non-null     int64
#  5   Segment                                 34 non-null     int64
#  6   Total number of estb                    34 non-null     int64
#  7   Product line sales as % of total sales  34 non-null     float64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 2.2+ KB

# %%
stores.dtypes.value_counts()
# Out:
# int64      5
# float64    2
# object     1
# dtype: int64

# %%
stores.Total_Sales.mean() , stores.Total_Sales.median()
# Out:
# (976465554.7647059, 961670525.5)

# %%
stores.Total_Customers.dtypes
# Out:
# dtype('int64')

# %%
stores.head()
# Out:
#    Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0     1  Electronincs           21.0   2179474632              110        4
# 1     2       Apparel           21.0      5037027              110        4
# 2     3  Super Market           22.8   1437362017               93        1
# 3     4  Super Market           21.4   1495953548              110        1
# 4     5  Super Market           18.7   1883321582              175        2
#
#    Total number of estb  Product line sales as % of total sales
# 0                361300                                    29.6
# 1                  2515                                     5.7
# 2                200112                                     5.9
# 3                229623                                     4.6
# 4                270472                                    24.7

# %%
# loc gets rows (and/or columns) with particular labels.

# iloc gets rows (and/or columns) at integer locations

## loc[ rows, columns]
## loc[logic, 1:5]


stores.loc[:,"StoreType"]
# Out:
# 0     Electronincs
# 1          Apparel
# 2     Super Market
# 3     Super Market
# 4     Super Market
# 5          Apparel
# 6          Apparel
# 7     Electronincs
# 8     Electronincs
# 9          Apparel
# 10    Super Market
# 11    Super Market
# 12    Super Market
# 13         Apparel
# 14         Apparel
# 15    Electronincs
# 16    Electronincs
# 17         Apparel
# 18    Super Market
# 19    Super Market
# 20    Super Market
# 21         Apparel
# 22         Apparel
# 23    Electronincs
# 24    Electronincs
# 25         Apparel
# 26    Super Market
# 27    Super Market
# 28    Super Market
# 29         Apparel
# 30         Apparel
# 31    Electronincs
# 32         Apparel
# 33    Electronincs
# Name: StoreType, dtype: object

# %%
stores.iloc[:,1:8]
# Out:
#        StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0   Electronincs           21.0   2179474632              110        4
# 1        Apparel           21.0      5037027              110        4
# 2   Super Market           22.8   1437362017               93        1
# 3   Super Market           21.4   1495953548              110        1
# 4   Super Market           18.7   1883321582              175        2
# 5        Apparel           18.1   1420570094              105        1
# 6        Apparel           14.3   1374569510              245        4
# 7   Electronincs           24.4   1094166173               62        2
# 8   Electronincs           22.8   1182772215               95        2
# 9        Apparel           19.2    891982615              123        4
# 10  Super Market           17.8    427475654              123        4
# 11  Super Market           16.4   1101543654              180        3
# ...

# %%
stores.iloc[1:3,1:4]
# Out:
#       StoreType  OperatingCost  Total_Sales
# 1       Apparel           21.0      5037027
# 2  Super Market           22.8   1437362017

# %%
stores.iloc[[1,2,10,11] , [0,1,5]]
# Out:
#     Code     StoreType  Segment
# 1      2       Apparel        4
# 2      3  Super Market        1
# 10    11  Super Market        4
# 11    12  Super Market        3

# %%
s1 = pd.Series([2434,56778,1234,"A","C"], index=[49, 48, 47, 0, 1])
s1
# Out:
# 49     2434
# 48    56778
# 47     1234
# 0         A
# 1         C
# dtype: object

# %%
s1.loc[0]
# Out:
# 'A'

# %%
s1.iloc[0]
# Out:
# 2434

# %%
stores.head()
# Out:
#    Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0     1  Electronincs           21.0   2179474632              110        4
# 1     2       Apparel           21.0      5037027              110        4
# 2     3  Super Market           22.8   1437362017               93        1
# 3     4  Super Market           21.4   1495953548              110        1
# 4     5  Super Market           18.7   1883321582              175        2
#
#    Total number of estb  Product line sales as % of total sales
# 0                361300                                    29.6
# 1                  2515                                     5.7
# 2                200112                                     5.9
# 3                229623                                     4.6
# 4                270472                                    24.7

# %%
### Renaming of columns

# df = df.rename(columns={'oldName1': 'newName1', 'oldName2': 'newName2'})

stores1 = stores.rename(columns={"Code":"Store_Code" , "OperatingCost":"Op_Cost"})
stores1.head()
# Out:
#    Store_Code     StoreType  Op_Cost  Total_Sales  Total_Customers  Segment  \
# 0           1  Electronincs     21.0   2179474632              110        4
# 1           2       Apparel     21.0      5037027              110        4
# 2           3  Super Market     22.8   1437362017               93        1
# 3           4  Super Market     21.4   1495953548              110        1
# 4           5  Super Market     18.7   1883321582              175        2
#
#    Total number of estb  Product line sales as % of total sales
# 0                361300                                    29.6
# 1                  2515                                     5.7
# 2                200112                                     5.9
# 3                229623                                     4.6
# 4                270472                                    24.7

# %%
### adding new col.
### method 1
stores['sales_per_cust'] = stores.Total_Sales / stores.Total_Customers

# %%
stores.head()
# Out:
#    Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0     1  Electronincs           21.0   2179474632              110        4
# 1     2       Apparel           21.0      5037027              110        4
# 2     3  Super Market           22.8   1437362017               93        1
# 3     4  Super Market           21.4   1495953548              110        1
# 4     5  Super Market           18.7   1883321582              175        2
#
#    Total number of estb  Product line sales as % of total sales  \
# 0                361300                                    29.6
# 1                  2515                                     5.7
# 2                200112                                     5.9
# 3                229623                                     4.6
# 4                270472                                    24.7
#
#    sales_per_cust
# 0    1.981341e+07
# 1    4.579115e+04
# 2    1.545551e+07
# 3    1.359958e+07
# 4    1.076184e+07

# %%
### method 2

stores = stores.assign(sales_per_cust1 = stores.Total_Sales / stores.Total_Customers)

# %%
stores.head()
# Out:
#    Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0     1  Electronincs           21.0   2179474632              110        4
# 1     2       Apparel           21.0      5037027              110        4
# 2     3  Super Market           22.8   1437362017               93        1
# 3     4  Super Market           21.4   1495953548              110        1
# 4     5  Super Market           18.7   1883321582              175        2
#
#    Total number of estb  Product line sales as % of total sales  \
# 0                361300                                    29.6
# 1                  2515                                     5.7
# 2                200112                                     5.9
# 3                229623                                     4.6
# 4                270472                                    24.7
#
#    sales_per_cust  sales_per_cust1
# 0    1.981341e+07     1.981341e+07
# 1    4.579115e+04     4.579115e+04
# ...

# %%
## where condition

## where(logic,T,F)

x = -10
print(np.where(x > 0, "positive","negative"))
# Out:
# negative

# %%
stores.head()
# Out:
#    Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0     1  Electronincs           21.0   2179474632              110        4
# 1     2       Apparel           21.0      5037027              110        4
# 2     3  Super Market           22.8   1437362017               93        1
# 3     4  Super Market           21.4   1495953548              110        1
# 4     5  Super Market           18.7   1883321582              175        2
#
#    Total number of estb  Product line sales as % of total sales  \
# 0                361300                                    29.6
# 1                  2515                                     5.7
# 2                200112                                     5.9
# 3                229623                                     4.6
# 4                270472                                    24.7
#
#    sales_per_cust  sales_per_cust1
# 0    1.981341e+07     1.981341e+07
# 1    4.579115e+04     4.579115e+04
# ...

# %%
### binning - converting a continuous variable into categorical var.

stores['stores_level'] = np.where(stores['Total number of estb']<10000, 'Low',
                                  
                                  np.where((stores['Total number of estb']>=10000)  & (stores['Total number of estb']<30000),
                                           
                                           'Medium', 'High'))

# %%
stores.head(20)
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0      1  Electronincs           21.0   2179474632              110        4
# 1      2       Apparel           21.0      5037027              110        4
# 2      3  Super Market           22.8   1437362017               93        1
# 3      4  Super Market           21.4   1495953548              110        1
# 4      5  Super Market           18.7   1883321582              175        2
# 5      6       Apparel           18.1   1420570094              105        1
# 6      7       Apparel           14.3   1374569510              245        4
# 7      8  Electronincs           24.4   1094166173               62        2
# 8      9  Electronincs           22.8   1182772215               95        2
# 9     10       Apparel           19.2    891982615              123        4
# 10    11  Super Market           17.8    427475654              123        4
# ...

# %%
# Applying conditions on a dataframe using loc[,]

stores.loc[stores.StoreType == "Super Market" , ["StoreType","OperatingCost"]]
# Out:
#        StoreType  OperatingCost
# 2   Super Market           22.8
# 3   Super Market           21.4
# 4   Super Market           18.7
# 10  Super Market           17.8
# 11  Super Market           16.4
# 12  Super Market           17.3
# 18  Super Market           30.4
# 19  Super Market           33.9
# 20  Super Market           21.5
# 26  Super Market           26.0
# 27  Super Market           30.4
# 28  Super Market           15.8

# %%
stores.loc[((stores.OperatingCost > 20) & (stores.OperatingCost < 30)) & ((stores.StoreType == "Super Market")|(stores.StoreType == "Electronincs")) , ["StoreType","OperatingCost"]]
# Out:
#        StoreType  OperatingCost
# 0   Electronincs           21.0
# 2   Super Market           22.8
# 3   Super Market           21.4
# 7   Electronincs           24.4
# 8   Electronincs           22.8
# 20  Super Market           21.5
# 26  Super Market           26.0
# 31  Electronincs           21.4
# 33  Electronincs           21.4

# %%
### sort the df

Sort2 = stores.sort_values(by = "OperatingCost")
Sort2
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 15    16  Electronincs           10.4   1070859930              215        4
# 14    15       Apparel           10.4    665220823              205        4
# 23    24  Electronincs           13.3    812748470              245        4
# 6      7       Apparel           14.3   1374569510              245        4
# 16    17  Electronincs           14.7    755438818              230        4
# 30    31       Apparel           15.0   1115016252              335        4
# 32    31       Apparel           15.0   1115016252              335        4
# 13    14       Apparel           15.2    960625804              180        3
# 22    23       Apparel           15.2    877566947              150        2
# 21    22       Apparel           15.5   1333254147              150        2
# 28    29  Super Market           15.8     22212234              264        4
# ...

# %%
Sort2 = stores.sort_values(by = "OperatingCost", ascending=False)
Sort2
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 19    20  Super Market           33.9    660175220               65        1
# 17    18       Apparel           32.4    953515932               66        1
# 18    19  Super Market           30.4    962715247               52        2
# 27    28  Super Market           30.4    886631610              113        2
# 25    26       Apparel           27.3   1099171980               66        1
# 26    27  Super Market           26.0    711375353               91        2
# 7      8  Electronincs           24.4   1094166173               62        2
# 2      3  Super Market           22.8   1437362017               93        1
# 8      9  Electronincs           22.8   1182772215               95        2
# 20    21  Super Market           21.5    672255327               97        1
# 31    32  Electronincs           21.4   1237304404              109        2
# ...

# %%
Sort4 = stores.sort_values(by = ["OperatingCost","Total number of estb"],ascending=[True,False])
Sort4
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 15    16  Electronincs           10.4   1070859930              215        4
# 14    15       Apparel           10.4    665220823              205        4
# 23    24  Electronincs           13.3    812748470              245        4
# 6      7       Apparel           14.3   1374569510              245        4
# 16    17  Electronincs           14.7    755438818              230        4
# 30    31       Apparel           15.0   1115016252              335        4
# 32    31       Apparel           15.0   1115016252              335        4
# 22    23       Apparel           15.2    877566947              150        2
# 13    14       Apparel           15.2    960625804              180        3
# 21    22       Apparel           15.5   1333254147              150        2
# 28    29  Super Market           15.8     22212234              264        4
# ...

# %%
### number of missing values

stores.isnull().sum()
# Out:
# Code                                      0
# StoreType                                 0
# OperatingCost                             0
# Total_Sales                               0
# Total_Customers                           0
# Segment                                   0
# Total number of estb                      0
# Product line sales as % of total sales    0
# sales_per_cust                            0
# sales_per_cust1                           0
# stores_level                              0
# dtype: int64

# %%
###s2 = stores[stores.sales_per_cust.isnull()]

# %%
## copy the df
stores1 = stores
stores1
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0      1  Electronincs           21.0   2179474632              110        4
# 1      2       Apparel           21.0      5037027              110        4
# 2      3  Super Market           22.8   1437362017               93        1
# 3      4  Super Market           21.4   1495953548              110        1
# 4      5  Super Market           18.7   1883321582              175        2
# 5      6       Apparel           18.1   1420570094              105        1
# 6      7       Apparel           14.3   1374569510              245        4
# 7      8  Electronincs           24.4   1094166173               62        2
# 8      9  Electronincs           22.8   1182772215               95        2
# 9     10       Apparel           19.2    891982615              123        4
# 10    11  Super Market           17.8    427475654              123        4
# ...

# %%
### duplicated records

stores_duplicated = stores.loc[stores.duplicated(),]
stores_duplicated
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 32    31       Apparel           15.0   1115016252              335        4
# 33    32  Electronincs           21.4   1237304404              109        2
#
#     Total number of estb  Product line sales as % of total sales  \
# 32                125658                                     7.5
# 33                123206                                     6.4
#
#     sales_per_cust  sales_per_cust1 stores_level
# 32    3.328407e+06     3.328407e+06         High
# 33    1.135142e+07     1.135142e+07         High

# %%
# Drop duplicates

stores_1 = stores.drop_duplicates()

# %%
#stores = stores.drop_duplicates()

# %%
stores_duplicated = stores_1.loc[stores.duplicated(),]
stores_duplicated
# Out:
# Empty DataFrame
# Columns: [Code, StoreType, OperatingCost, Total_Sales, Total_Customers, Segment, Total number of estb, Product line sales as % of total sales, sales_per_cust, sales_per_cust1, stores_level]
# Index: []
